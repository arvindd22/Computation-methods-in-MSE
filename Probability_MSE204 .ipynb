# %%
import numpy as np
import matplotlib.pyplot as plt

# Possible outcomes for a single die throw
outcomes = [1, 2, 3, 4, 5, 6,7]

# Probability of each outcome
prob = 1 / 6

# Create a bar plot for the probability mass function
# plt.bar(outcomes, [prob] * len(outcomes), color='b', label='Probability')

# Mark all points with "*"
plt.scatter(outcomes, [prob] * len(outcomes), color='r', marker='*', label='Marked Points')

plt.xlabel("Outcome")
plt.ylabel("Probability")
plt.title("Probability mass function of Single Dice throw")
plt.legend()

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Simulate all possible outcomes of rolling two dice
outcomes = np.arange(2, 13)  # Possible sums range from 2 to 12
# probabilities = [1/36, 2/36, 3/36, 4/36, 5/36, 6/36, 5/36, 4/36, 3/36, 2/36, 1/36]# this is not best method  because we use numpy
probabilities = np.array([1,2,3,4,5,6,5,4,3,2,1])/36

# Create a bar plot
plt.scatter(outcomes, probabilities, color='b', alpha=0.7)
plt.xlabel("Sum of Dice Rolls")
plt.ylabel("Probability")
plt.title("Probability Distribution of Sums of Two Dice Rolls")
plt.xticks(np.arange(2, 13))
plt.grid(axis='y', alpha=0.75)

plt.show()

# %%
import matplotlib.pyplot as plt

# Calculate probabilities for each sum
probabilities = [0] * 11  # Initialize list to store probabilities
total_outcomes = 0

for die1 in range(1, 7):
    for die2 in range(1, 7):
        total_outcomes += 1
        probabilities[die1 + die2 - 2] += 1

# Normalize probabilities
probabilities = [prob / total_outcomes for prob in probabilities]

# Create a bar plot
outcomes = range(2, 13)
plt.bar(outcomes, probabilities, color='b', alpha=0.7 , label='PMF')
plt.xlabel("Sum of Dice Rolls")
plt.ylabel("Probability")
plt.title("Probability Distribution of Sums of Two Dice Rolls")
plt.xticks(outcomes)
plt.grid(axis='y', alpha=0.75)
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the possible sums and their corresponding probabilities
# possible_sums = list(range(2, 13))  # this is not best method , best method using numpy
possible_sums = np.arange(2,13)
# probabilities = [1/36, 2/36, 3/36, 4/36, 5/36, 6/36, 5/36, 4/36, 3/36, 2/36, 1/36] # this is not best method , best method using numpy
probabilities = np.array([1, 2, 3, 4, 5, 6, 5, 4, 3, 2, 1]) / 36
# Calculate cumulative probabilities
# cumulative_probabilities = [sum(probabilities[:i+1]) for i in range(len(possible_sums))]  # this is not best method
#  if you remove numpy then all those line work that commented by line this is not best method
cumulative_probabilities = np.cumsum(probabilities)

# Create the plot
plt.figure(figsize=(10, 6))

# Cumulative Probability Plot
plt.step(possible_sums, cumulative_probabilities, where='mid', label='Cumulative Probability', color='blue')

# Probability Plot
plt.bar(possible_sums, probabilities, alpha=0.5, label='Probability', color='gray')

# Adding labels and title
plt.xlabel('Sum of Two Dice')
plt.ylabel('Probability')
plt.title('Cumulative Probability Distribution of Throwing Two Dice')
plt.legend()
plt.xticks(np.arange(2,13))
# Display the plot
plt.grid()
plt.show()

# %%
# we draw both cumulative and geomtric distribution from one code
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from scipy import stats
from scipy.stats import geom
x = np.arange(2,13)
probabilities = np.array([1,2,3,4,5,6,5,4,3,2,1])/36
cumulative_distribution = np.cumsum(probabilities)
fig ,axes = plt.subplots(ncols = 2, nrows = 1 , figsize = (10,6))
# we want to plot first cumulative and in second simple probability vs outcome
# cumulative plot
axes[0].step(x,cumulative_distribution,label = 'cumulative distribution', color = 'r')
axes[0].set_xlabel("Outcome (sum of two diece)")
axes[0].set_ylabel("Cumulative Probability")
axes[0].set_title("Cumulative distribution function")
# Probability Plot
axes[1].bar(x ,probabilities, label='Probability distribution', color='gray')
axes[1].set_xlabel("Outcome")
axes[1].set_ylabel("Probability of outcome")
axes[1].set_title("probability distribution function")
# Out:
# Text(0.5, 1.0, 'probability distribution function')

# %%
#  simple geometric distribution
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
p = 0.4
x = np.arange(1,17)
y = stats.geom.pmf(x,p)
# Plotting
plt.figure(figsize=(10,7))
plt.xlabel("Probability of success after which point")
plt.ylabel("Probability of success")
plt.title("Geometric distribution")
plt.bar(x,y)
# plt.xticks(np.arange(1,17))
# Out:
# <BarContainer object of 16 artists>

# %%
#Geometric distribution with shoe mean and medain
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
from scipy.stats import geom
p = 0.4
x = np.arange(1,17)
y = stats.geom.pmf(x,p)
mean = geom.mean(p)
median = geom.median(p)
# Plotting
plt.figure(figsize=(10,7))
plt.xlabel("Probability of success after which point")
plt.ylabel("Probability of success")
plt.title("Geometric distribution")
plt.bar(x,y)
plt.axvline(mean, color='r', linestyle='dashed', label='mean')
plt.axvline(median, color='g', linestyle='dashed', label='mean')

# %%
# For cumulative distribution function
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
from scipy.stats import geom
p = 0.4
x = np.arange(1,17)
y = stats.geom.cdf(x,p)
mean = geom.mean(p)
median = geom.median(p)
# Plotting
plt.figure(figsize=(10,7))
plt.xlabel("Probability of success after which point")
plt.ylabel("Probability of success")
plt.title("Geometric distribution")
plt.step(x,y)
plt.axvline(mean, color='r', linestyle='dashed', label='mean')
plt.axvline(median, color='g', linestyle='dashed', label='mean')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
from scipy.stats import geom
p_value =[0.4,0.2]
x = np.arange(1,21)
fig, axes = plt.subplots(ncols = 2 , nrows = len(p_value), figsize = (10, 6*len(p_value)))
for i, p in enumerate(p_value):
    pmf = stats.geom.pmf(x,p)
    cdf = geom.cdf(x,p)
    mean = geom.mean(p)
    median = geom.median(p)
#     for plot PMF
    axes[i,0].bar(x,pmf , label='PMF', color='yellow')
    axes[i,0].set_xlabel("X")
    axes[i,0].set_ylabel("Probability of outcomes")
    axes[i,0].set_title("Probability mass function Graph")
    axes[i,0].axvline(mean ,color='r',alpha = 0.7 , linestyle = 'dashed',label= 'mean')
    axes[i,0].axvline(median ,color='gray',alpha = 0.7 , linestyle = 'dashed' , label = 'median')
    axes[i, 0].legend()  # from this line label will occur

#      for plot CDF
    axes[i,1].step(x,cdf , label='CDF', color='red')
    axes[i,1].axvline(median, color='g', linestyle='dashed', label='Median')
    axes[i,1].axhline(0.5 , color='b' , linestyle = 'dashed',label= 'f(x) = 0.5' )
    axes[i,1].legend()
plt.tight_layout()
plt.show()

# %%
# Question:--> 100 samples are kept in a box and 10 of them are defective. We randomly
# pick a sample from the box. If the sample is not defective, we put it back to the box and
# randomly pick another sample from the box. This is known as sampling with replacement.
# What is the probability that we find a defective sample at xth trial? The probability that
# a sample is defective and non-defective is p = 10/100 and (1 − p) = 90/100, respectively.12
# Probability of getting a defective sample in the first trial is P(X = 1) = p. Probability of
# getting a defective sample in the second trial is equal to the probability of getting a nondefective sample in the first trial times the probability of getting a defective sample in the
# second trial: P(X = 2) = (1 − p)p. Similarly, we can write,

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
from scipy.stats import geom
p = 10/100
x= np.arange(1,21)
pmf= (1-p)**(x-1) *p
plt.bar(x,pmf, label= 'PMF')
plt.xlabel("No of round taken to get defective particels")
plt.ylabel("Probability of getting success")
plt.title("Probability of removing defective particle")
plt.xticks(np.arange(1,21))
plt.legend()
plt.show()

# %%
# 13.3.5 Exercise Question -1
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from scipy.stats import geom
x = np.arange(0,6)
probabilty_defective = np.array([0.8, 0.08,0.05,0.04, 0.02,0.01])
mean = np.sum(x*probabilty_defective)
variance = np.sum((x-mean)**2 * probabilty_defective)
print("variance:-->", variance)
print("mean:-->", mean)
# Out:
# variance:--> 1.0251000000000001
# mean:--> 0.43

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from scipy.stats import geom
x = np.arange(2,13)
probabilty_defective = np.array([1,2,3,4,5,6,5,4,3,2,1])/36
mean = np.sum(x*probabilty_defective)
variance = np.sum((x-mean)**2 * probabilty_defective)
print("variance:-->", variance)
print("mean:-->", mean)
# Out:
# variance:--> 5.833333333333333
# mean:--> 6.999999999999998

# %%
# no of head obtain after tossing 4 coins
import numpy as np
import pandas as pd
import matplotlib.pyplot
no_of_head = np.arange(0,5)
probabilty_of_head = np.array([1,4,6,4,1])/16
fig ,axes = plt.subplots(ncols = 2 , nrows =1, figsize = (10,6))
cumulative_probability = np.cumsum(probabilty_of_head)
# Plot PMF
axes[0].bar(no_of_head ,probabilty_of_head)
axes[0].set_xlabel("No of head")
axes[0].set_ylabel("probability of geeting head")
axes[0].set_title("Probability mass function")
axes[0].legend()
#  Plot cumulative probability
axes[1].step(no_of_head,cumulative_probability)
axes[1].set_xlabel("No of head")
axes[1].set_ylabel("cumulative")
axes[1].set_title("cumulative probability")
plt.tight_layout()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# Analytic normal distribution
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from scipy.stats import geom
mu, sigma = 0,2
x = np.linspace(mu-3*sigma, mu+3*sigma, 100)
y = stats.norm.pdf(x,mu,sigma)
yc =stats.norm.cdf(x,mu,sigma)
fig, axes = plt.subplots(ncols = 2 , nrows= 1 , figsize= (10,6))
axes[0].plot(x,y)
axes[1].plot(x,yc)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from sklearn import preprocessing
from scipy.stats import geom
mu ,sigma = 3,5
df = pd.DataFrame({'X': np.random.normal(mu,sigma ,2500)})
print(df.describe())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[19], line 4
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
# ----> 4 import seaborn as sns
#       5 from scipy import stats
#       6 from sklearn import preprocessing
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
# Min-Max Scaling   --> Remeber this things
scaler = preprocessing.MinMaxScaler()
minmax_df = scaler.fit_transform(df)
minmax_df = pd.DataFrame(minmax_df, columns=["Y"])
print(minmax_df.describe())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-220ac9d8d531> in <cell line: 2>()
#       1 # Min-Max Scaling   --> Remeber this things
# ----> 2 scaler = preprocessing.MinMaxScaler()
#       3 minmax_df = scaler.fit_transform(df)
#       4 minmax_df = pd.DataFrame(minmax_df, columns=["Y"])
#       5 print(minmax_df.describe())
#
# NameError: name 'preprocessing' is not defined

# %%
# Standard - Scaling
scaler = preprocessing.StandardScaler()
standard_df = scaler.fit_transform(df)
standard_df = pd.DataFrame(standard_df,columns=["Z"])
print(standard_df.describe())
# Out:
#                   Z
# count  2.500000e+03
# mean   2.842171e-18
# std    1.000200e+00
# min   -3.738585e+00
# 25%   -6.687856e-01
# 50%   -3.223375e-02
# 75%    6.718712e-01
# max    3.058592e+00

# %%
# Plotting
fig = plt.figure(figsize = (10,7))
ax1= fig.add_subplot(3,1,1)
ax2= fig.add_subplot(3,1,2)
ax3= fig.add_subplot(3,1,3)
ax1.set_title("Before Scaling")
sns.histplot(df['X'], ax= ax1, color = 'r')
ax2.set_title("after Scaling")
sns.histplot(minmax_df['Y'], ax= ax2, color = 'b')
ax3.set_title("standard Scaling")
sns.histplot(standard_df['Z'], ax= ax3, color = 'y')
# Out:
# <Axes: title={'center': 'standard Scaling'}, xlabel='Z', ylabel='Count'>

# %%
# Binomial Distribution
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
n = 20
p1 = 0.05
p2 = 0.20
p3 = 0.60
x = range(0,n+1)
y1 = stats.binom.cdf(x,n,p1)
y2 = stats.binom.cdf(x,n,p2)
y3 = stats.binom.cdf(x,n,p3)
plt.figure(figsize=(10,6))
plt.step(x,y1 ,"-o",label = "p="+str(p1)+" ,n="+str(n))
plt.step(x,y2, "-s",label = "p="+str(p2)+",n="+str(n))
plt.step(x,y3, "-d",label = "p="+str(p2)+",n="+str(n))
plt.xlabel("X")
plt.ylabel("F(x)")
plt.legend()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
n = 20
p1 = 0.05
p2 = 0.20
p3 = 0.60
x = range(0,n+1)
y1 = stats.binom.pmf(x,n,p1)
y2 = stats.binom.pmf(x,n,p2)
y3 = stats.binom.pmf(x,n,p3)
plt.figure(figsize=(10,6))
plt.bar(x,y1,color='y' ,label = "p="+str(p1)+" ,n="+str(n), alpha =0.7, width= 0.1)
plt.bar(x,y2, color='b' ,label = "p="+str(p2)+",n="+str(n), width = 0.2)
plt.bar(x,y3, color='r',label = "p="+str(p2)+",n="+str(n))
plt.xlabel("X")
plt.ylabel("F(x)")
plt.legend()

# %%
from scipy import stats
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import geom
n=30
p =0.1
# code for exactly five sucess
print("Probability for exactly Five success: ",stats.binom.pmf(5,n,p))
mean,var = stats.binom.stats(n,p)
print("Average", mean , "Variance", var)
x = np.arange(n+1)
prob = stats.binom.pmf(x,n,p)
prob_cumulat= stats.binom.cdf(x,n,p)
fig,axes = plt.subplots(ncols = 2, nrows =1, figsize=(10,6))
axes[0].bar(x,prob)
axes[0].set_xlabel("Number of defective items")
axes[0].set_ylabel("Probability")
axes[1].step(x,prob_cumulat)
axes[1].set_xlabel("Number of defective items")
axes[1].set_ylabel("Cumulative Probability function")
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Probability for exactly Five success:  0.10230477063401515
# Average 3.0 Variance 2.7

# %%
#  but the use those code that given in notes
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
n=30
p=0.1
print("Probability of exactly five success " ,stats.binom.pmf(5,n,p))
mean , var = stats.binom.stats(n,p)
x= np.arange(n+1)
prob = stats.binom.pmf(x,n,p)
prob_cumul= stats.binom.cdf(x,n,p)
fig, axes = plt.subplots(ncols = 2, nrows =1 , figsize = (10,7))
# creatin data frame for sucessing the probability
binomial_df = pd.DataFrame({"Success": x, "Probability": prob})
print(binomial_df )
# creatin data frame for cumulative probability
binomial_cumulative_df = pd.DataFrame({"Success": x , "CumulativeProbability":prob_cumul})
print(binomial_cumulative_df )
# Remember next line
sns.barplot(x=binomial_df.Success, y= binomial_df.Probability ,ax = axes[0])
axes[0].set_xlabel("Number of defective items")
axes[0].set_ylabel("probability of finding defective item")
axes[0].set_title("Probability")
# Cumulative plot
sns.barplot(x=binomial_cumulative_df.Success, y= binomial_cumulative_df.CumulativeProbability ,ax =axes[1] )
#axes[1].step(x=binomial_cumulative_df.Success, y= binomial_cumulative_df.CumulativeProbability )  # this line for step type graph
axes[1].set_xlabel("Number of defective items")
axes[1].set_ylabel("probability of finding defective item")
axes[1].set_title("Cumulataive Probability")
plt.legend()
plt.show()
# Out:
# Probability of exactly five success  0.10230477063401511
#     Success   Probability
# 0         0  4.239116e-02
# 1         1  1.413039e-01
# 2         2  2.276562e-01
# 3         3  2.360879e-01
# 4         4  1.770659e-01
# 5         5  1.023048e-01
# 6         6  4.736332e-02
# 7         7  1.804317e-02
# 8         8  5.763790e-03
# 9         9  1.565474e-03
# 10       10  3.652772e-04
# 11       11  7.379338e-05
# 12       12  1.298217e-05
# 13       13  1.997257e-06
# 14       14  2.694712e-07
# 15       15  3.193732e-08
# 16       16  3.326804e-09
# 17       17  3.044135e-10
# 18       18  2.442824e-11
# 19       19  1.714263e-12
# 20       20  1.047605e-13
# 21       21  5.542883e-15
# 22       22  2.519492e-16
# 23       23  9.737168e-18
# 24       24  3.155564e-19
# 25       25  8.414837e-21
# 26       26  1.798042e-22
# 27       27  2.959740e-24
# 28       28  3.523500e-26
# 29       29  2.700000e-28
# 30       30  1.000000e-30
#     Success  CumulativeProbability
# ...

# %%
# cumulative distribution plot
# Normal and gaussinan distribution
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
mu ,sigma =10,2
x= np.linspace(mu-4*sigma, mu+4*sigma ,100)
x1= np.linspace(mu-4*sigma, mu ,100)
x2= np.linspace(mu-4*sigma, mu+sigma ,100)
x3= np.linspace(mu-4*sigma, mu-sigma ,100)
y =stats.norm.pdf(x,mu,sigma)
y1=stats.norm.pdf(x1,mu,sigma)
y2=stats.norm.pdf(x2,mu,sigma)
y3=stats.norm.pdf(x3,mu,sigma)
yc= stats.norm.cdf(x,mu,sigma)
fig ,axes=  plt.subplots(ncols = 2 , nrows = 2, figsize =(20,10))
axes[0,0].plot(x,y)
axes[0,0].fill_between(x1,y1, color='r')
axes[0,1].plot(x,y)
axes[0,1].fill_between(x2,y2)
axes[1,0].plot(x,y)
axes[1,0].fill_between(x3,y3)
axes[1,1].plot(x,y)
axes[1,1].fill_between(x,yc)

# %%
# value of Φ(x) or Φ(z) using stats.norm.cdf. Conversely, given the value of Φ, we can find the
# value of x(Φ) or z(Φ) by using stats.norm.ppf.
from scipy import stats
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import norm
mu , sigma =10,2
# given phi(x) , find the value of x
#  for value of x and z using:-->  stats.norm.ppf

x= stats.norm.ppf(0.8413447460685429,mu, sigma)
z=stats.norm.ppf(0.8413447460685429)
# #  for value of phi(x) and phi(z) using:--> stats.norm.cdf
#  value of phi(x)
phi_x = stats.norm.cdf(12,mu,sigma)
#  value of phi(z)
phi_z=  stats.norm.cdf(1)
print("value of x", x , " ,value of Z" ,z,' ,value of phi(x)' ,phi_x , " ,value 0f phi(z)", phi_z)
# Out:
# value of x 12.0  ,value of Z 1.0  ,value of phi(x) 0.8413447460685429  ,value 0f phi(z) 0.8413447460685429

# %%
# Another method of some code
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
from sklearn import preprocessing

mu, sigma = 3, 5
df = pd.DataFrame({'X': np.random.normal(mu, sigma, 2500)})

print(df.describe())

# Min-Max Scaling
scaler = preprocessing.MinMaxScaler()
minmax_df = scaler.fit_transform(df)

# Standard Scaling
scaler = preprocessing.StandardScaler()
standard_df = scaler.fit_transform(df)

# Plotting
fig, axes = plt.subplots(nrows=3, ncols=1, figsize=(10, 14))

# Before Scaling
axes[0].set_title("Before Scaling")
sns.histplot(df['X'], bins=30, color='r',ax= axes[0])

# After Min-Max Scaling
axes[1].set_title("After Min-Max Scaling")
sns.histplot(minmax_df, bins=30, color='b', ax= axes[1])

# After Standard Scaling
axes[2].set_title("After Standard Scaling")
sns.histplot(standard_df, bins=30, color='gray',ax=axes[2])

plt.tight_layout()
plt.show()
# Out:
#                  X
# count  2500.000000
# mean      2.967197
# std       5.034266
# min     -13.554230
# 25%      -0.339991
# 50%       2.930184
# 75%       6.223922
# max      17.750741

# %%
df=pd.read_csv("concrete_data.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 df=pd.read_csv("concrete_data.csv")
#
# File c:\Users\Arvind Devkate\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
# Analytic normal distribution
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from scipy.stats import geom
mu, sigma = 0,2
x = np.linspace(mu-3*sigma, mu+3*sigma, 100)
y = stats.norm.pdf(x,mu,sigma)
yc =stats.norm.cdf(x,mu,sigma)
fig, axes = plt.subplots(ncols = 2 , nrows= 1 , figsize= (10,6))
axes[0].plot(x,y)
axes[1].plot(x,yc)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[22], line 5
#       3 import pandas as pd
#       4 import matplotlib.pyplot as plt
# ----> 5 import seaborn as sns
#       6 from scipy import stats
#       7 from scipy.stats import geom
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
from scipy.stats import norm

# Given values
mu = 0
sigma = 1

# Calculate cumulative probabilities using the CDF
prob_1_sigma = norm.cdf(mu + sigma, mu, sigma) - norm.cdf(mu - sigma, mu, sigma)
prob_2_sigma = norm.cdf(mu + 2 * sigma, mu, sigma) - norm.cdf(mu - 2 * sigma, mu, sigma)
prob_3_sigma = norm.cdf(mu + 3 * sigma, mu, sigma) - norm.cdf(mu - 3 * sigma, mu, sigma)

print("P(µ - σ < X < µ + σ):", prob_1_sigma)
print("P(µ - 2σ < X < µ + 2σ):", prob_2_sigma)
print("P(µ - 3σ < X < µ + 3σ):", prob_3_sigma)
# Out:
# P(µ - σ < X < µ + σ): 0.6826894921370859
# P(µ - 2σ < X < µ + 2σ): 0.9544997361036416
# P(µ - 3σ < X < µ + 3σ): 0.9973002039367398

# %%
from scipy.stats import norm

# Calculate cumulative probabilities using the CDF
prob_Z_leq_neg1_54 = norm.cdf(-1.54)
prob_Z_gt_neg1_54 = 1 - norm.cdf(-1.54)
prob_Z_leq_1_02 = norm.cdf(1.02)
prob_Z_gt_1_02 = 1 - norm.cdf(1.02)
prob_Z_leq_0_28 = norm.cdf(0.28)
prob_Z_gt_0_28 = 1 - norm.cdf(0.28)
prob_0_28_lt_Z_lt_1_02 = norm.cdf(1.02) - norm.cdf(0.28)

# Find z such that P(Z ≤ z) = 0.770350
z_for_prob_0_770350 = norm.ppf(0.770350)

# Find z such that P(Z > z) = 0.0968
z_for_prob_gt_0_0968 = norm.ppf(1 - 0.0968)

print("P(Z ≤ -1.54):", prob_Z_leq_neg1_54)
print("P(Z > -1.54):", prob_Z_gt_neg1_54)
print("P(Z ≤ 1.02):", prob_Z_leq_1_02)
print("P(Z > 1.02):", prob_Z_gt_1_02)
print("P(Z ≤ 0.28):", prob_Z_leq_0_28)
print("P(Z > 0.28):", prob_Z_gt_0_28)
print("P(0.28 < Z < 1.02):", prob_0_28_lt_Z_lt_1_02)
print("z for P(Z ≤ z) = 0.770350:", z_for_prob_0_770350)
print("z for P(Z > z) = 0.0968:", z_for_prob_gt_0_0968)
# Out:
# P(Z ≤ -1.54): 0.061780176711811886
# P(Z > -1.54): 0.9382198232881881
# P(Z ≤ 1.02): 0.8461357696272652
# P(Z > 1.02): 0.15386423037273478
# P(Z ≤ 0.28): 0.6102612475557972
# P(Z > 0.28): 0.38973875244420275
# P(0.28 < Z < 1.02): 0.23587452207146797
# z for P(Z ≤ z) = 0.770350: 0.7399999906548795
# z for P(Z > z) = 0.0968: 1.3000028277439595

# %%
#Q-10
from scipy.stats import norm

# Given parameters
mu = 10
sigma = 2  # Square root of variance

# Z-score corresponding to the 98th percentile
z_98_percentile = norm.ppf(0.98)

# Calculate the corresponding thickness
thickness_98_percentile = mu + z_98_percentile * sigma
print("98% of coatings have thickness ≤", thickness_98_percentile, "mm")
# Out:
# 98% of coatings have thickness ≤ 14.107497821263646 mm

# %%
# Q-11
from scipy.stats import norm

# Given parameters
mu = 0
sigma = 2

# Find the probability of detecting a false signal (value ≥ 4)
prob_false_signal = 1 - norm.cdf(4, mu, sigma)

print("Probability of detecting a false signal:", prob_false_signal)
# Out:
# Probability of detecting a false signal: 0.02275013194817921

# %%
# Exercise 13: Wasted Coated Glass Plates
from scipy.stats import norm

# Given parameters
mu = 10
sigma = 2

# Standardize the lower and upper bounds of the accepted dimension
z_lower = (9 - mu) / sigma
z_upper = (11 - mu) / sigma

# Calculate the probability that coating thickness is outside the range
prob_outside_range = norm.cdf(z_lower) + (1 - norm.cdf(z_upper))

# Calculate the fraction of coated glass plates wasted
fraction_wasted = prob_outside_range

print("Fraction of coated glass plates wasted:", fraction_wasted)
# Out:
# Fraction of coated glass plates wasted: 0.6170750774519738

# %%
#Understanding the Limitations of Normal Approximation
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import binom, norm

# Parameters for the binomial distribution
n_values = [10, 10, 10, 50, 50, 50]
p_values = [0.5, 0.1, 0.9, 0.5, 0.1, 0.9]

# Create bar plots of binomial distribution and normal approximation
for n, p in zip(n_values, p_values):
    x = np.arange(0, n+1)
    binom_dist = binom.pmf(x, n, p)

    # Calculate mean and variance for normal approximation
    mu = n * p
    sigma = np.sqrt(n * p * (1 - p))
    norm_approx = norm.pdf(x, mu, sigma)

    plt.figure(figsize=(10, 4))
    plt.subplot(1, 2, 1)
    plt.bar(x, binom_dist, label='Binomial Distribution')
    plt.xlabel('X')
    plt.ylabel('Probability')
    plt.title(f'n = {n}, p = {p}')

    plt.subplot(1, 2, 2)
    plt.bar(x, binom_dist, label='Binomial Distribution')
    plt.plot(x, norm_approx, 'r', label='Normal Approximation')
    plt.xlabel('X')
    plt.ylabel('Probability')
    plt.title(f'n = {n}, p = {p}')
    plt.legend()

    plt.tight_layout()
    plt.show()

# %%
#Exercise 16: Press Rejected Pages Problem
from scipy.stats import binom

# Given probability and number of pages
p = 10**(-3)
n = 100000

# Find the probability that exactly 100 pages are rejected
prob_100_rejected = binom.pmf(100, n, p)

# Find the probability that not more than 100 pages are rejected
prob_not_more_than_100_rejected = binom.cdf(100, n, p)

print("Probability that exactly 100 pages are rejected:", prob_100_rejected)
print("Probability that not more than 100 pages are rejected:", prob_not_more_than_100_rejected)
# Out:
# Probability that exactly 100 pages are rejected: 0.0398809422346256
# Probability that not more than 100 pages are rejected: 0.5265622018550735
